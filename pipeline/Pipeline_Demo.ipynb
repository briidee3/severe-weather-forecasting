# %% [markdown]
# ## Setting up OCTANE

# %% [markdown]
# Prior to running any of the below, copy `OCTANE-master.zip` into the local folder (in CoLab, this defaults to `/content/`).

# %% [markdown]
# ### Setting up environment for building OCTANE

# %%
import os
import xarray as xr

base_dir = os.getcwd()

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2023 NVIDIA Corporation
# Built on Tue_Aug_15_22:02:13_PDT_2023
# Cuda compilation tools, release 12.2, V12.2.140
# Build cuda_12.2.r12.2/compiler.33191640_0

# %%
# %pip install netcdf4

# %%
# !apt install libnetcdf-c++4-dev
# !apt install netcdf-bin netcdf-doc
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# libnetcdf-c++4-dev is already the newest version (4.3.1-3build1).
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# netcdf-bin is already the newest version (1:4.8.1-1).
# netcdf-doc is already the newest version (1:4.8.1-1).
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.

# %% [markdown]
# ### Building OCTANE

# %%
os.chdir('/content')
# !unzip OCTANE-master.zip
#!cd OCTANE-master/src/
#!make
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: OCTANE-master/netcdf-libs/nczarr_test/run_strings.sh
#   inflating: OCTANE-master/netcdf-libs/nczarr_test/run_unknown.sh
#   inflating: OCTANE-master/netcdf-libs/nczarr_test/run_ut_chunk.sh
#   inflating: OCTANE-master/netcdf-libs/nczarr_test/run_ut_map.sh
#   inflating: OCTANE-master/netcdf-libs/nczarr_test/run_ut_mapapi.sh
#   inflating: OCTANE-master/netcdf-libs/nczarr_test/run_ut_misc.sh
#   inflating: OCTANE-master/netcdf-libs/nczarr_test/s3util.c
#   inflating: OCTANE-master/netcdf-libs/nczarr_test/testfilter.c
#   inflating: OCTANE-master/netcdf-libs/nczarr_test/testfilter_misc.c
#   inflating: OCTANE-master/netcdf-libs/nczarr_test/testfilter_multi.c
#   inflating: OCTANE-master/netcdf-libs/nczarr_test/testfilter_order.c
#   inflating: OCTANE-master/netcdf-libs/nczarr_test/testfilter_repeat.c
#   inflating: OCTANE-master/netcdf-libs/nczarr_test/test_filter_avail.c
# ...

# %%
os.chdir('/content/OCTANE-master/src/')
# !make
# Out:
# nvcc -c -o ../build/oct_variational_optical_flow.o -gencode=arch=compute_75,code=sm_75 --std=c++11 -rdc=true -g -O3 -I ../include -I /usr/local/cuda/samples/common/inc  oct_variational_optical_flow.cu
# nvcc -dlink -o ../build/jCGlink.o -gencode=arch=compute_75,code=sm_75 ../build/oct_variational_optical_flow.o
# g++ -c -o ../build/oct_util.o oct_util.cc -g -O3 -I /usr/include -I /usr/include -I ../include
# g++ -c -o ../build/oct_bicubic.o oct_bicubic.cc -g -O3 -I /usr/include -I /usr/include -I ../include
# g++ -c -o ../build/oct_zoom.o oct_zoom.cc -g -O3 -I /usr/include -I /usr/include -I ../include
# g++ -c -o ../build/oct_gaussian.o oct_gaussian.cc -g -O3 -I /usr/include -I /usr/include -I ../include
# g++ -c -o ../build/oct_normalize_geo.o oct_normalize_geo.cc -g -O3 -I /usr/include -I /usr/include -I ../include
# g++ -c -o ../build/oct_fileread.o oct_fileread.cc -g -O3 -I /usr/include -I /usr/include -I ../include
# ...

# %%
os.chdir('/content')
# !cp OCTANE-master/build/octane .
# !chmod +x ./octane
# !./octane
# Out:
# Beginning variational dense optical flow...
# Optical Flow Toolkit for Atmospheric aNd Earth sciences (OCTANE)
# Author: Jason Apke
# Contact: jason.apke@colostate.edu
# input flags:
#
# -i1 <filename>, -i2 <filename> are the GOES-R file netcdf full paths, i1 is the first image, i2 is the second
#
# -i1cth <filename>, -i2cth <filename> are optional paths to cloud top height netcdfs
#
# -nncth instead of default bilinear interpolation, remap the CTH grids with nearest neighbor
#
# -o <directory> writes the file to the designated directory, include slash at the end (default is ./)
#
# -pd forces OCTANE to return unnavigated pixel displacements
#
# -srsal has OCTANE return bilinearly smoothed optical flow output (useful for computing cloud-top divergence)
#
# -Polar use this flag to ingest polar-orthonormal grid images instead of GOES projections (used for sea-ice tracking)
#
# -Merc use this flag to injest mercator grid images instead of GOES projections (definition)
#
# ...

# %% [markdown]
# # Main program

# %% [markdown]
# ### Important notes:

# %% [markdown]
# Prior to use, make sure you have done the following:
# - Edit the parameters in `main.py` to reflect your use case
# - Put your data in the local directory where all of this is being run (for example, a `GOES-R` directory inside `/content/` on CoLab) which contains directories pertaining to the days of which the data being investigated pertain to, such as `4-07` (e.g. `/content/GOES-R/4-07/`)
# - Copy the scripts tothe base directory where you're working from (e.g. `/content/`)
# - Built OCTANE

# %%
# !python main.py
# Out:
# Getting day: 4-06
#
# 	Getting data for hour: 00
# 		Extracting archive: OR_ABI-L1b_g16_meso_20220406_00.tar.gz
# 		Getting files...
# 			Currently moving OR_ABI-L1b-RadM2-M6C09_G16_s20220960000549_e20220960001012_c20220960001052.nc...
# 			Currently moving OR_ABI-L1b-RadM2-M6C11_G16_s20220960000549_e20220960001006_c20220960001057.nc...
# 			Currently moving OR_ABI-L1b-RadM2-M6C08_G16_s20220960000549_e20220960001006_c20220960001052.nc...
# 			Currently moving OR_ABI-L1b-RadM2-M6C08_G16_s20220960005549_e20220960006006_c20220960006055.nc...
# 			Currently moving OR_ABI-L1b-RadM2-M6C11_G16_s20220960005549_e20220960006006_c20220960006061.nc...
# 			Currently moving OR_ABI-L1b-RadM2-M6C09_G16_s20220960005549_e20220960006012_c20220960006059.nc...
# 			Currently moving OR_ABI-L1b-RadM2-M6C08_G16_s20220960010549_e20220960011006_c20220960011053.nc...
# 			Currently moving OR_ABI-L1b-RadM2-M6C11_G16_s20220960010549_e20220960011006_c20220960011058.nc...
# ...
